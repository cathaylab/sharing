# %% [markdown]
# # bokeh.plotting example

# %%
from bokeh.plotting import figure
from bokeh.io import output_notebook, show

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="219aeba1-b51a-411f-ba83-41edf8052a04">Loading BokehJS ...</span>
#     </div>

# %%
# this col_from_web has been added to the example and should be updated by the col attribute coming in through /plot/<col>
col_from_web ="green"
a = 10
col = 'red'

# prepare some data
x = [0.1, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
y0 = [i**2 for i in x]
y1 = [a**i for i in x]
y2 = [a**(i**2) for i in x]

# create a new plot
p = figure(
   tools="pan,wheel_zoom,box_zoom,box_select,lasso_select",
   y_axis_type="log", y_range=[0.001, 10**11], title="log axis example",
   x_axis_label='sections', y_axis_label='particles'
)

# add some renderers
p.line(x, x, legend="y=x")
p.circle(x, x, legend="y=x", fill_color="white", size=8)
p.line(x, y0, legend="y=x^2", line_width=3)
p.line(x, y1, legend="y=10^x", line_color=col)
p.circle(x, y1, legend="y=10^x", fill_color=col, line_color=col, size=6)
p.line(x, y2, legend="y=10^x^2", line_color="orange", line_dash="4 4")

# show the results
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="2e43af01-f178-49d3-80c8-52addd6b7955"></div>
# </div>
